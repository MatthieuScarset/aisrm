# %% [markdown]
# # Example notebook

# %%
# Load and work with the raw dataset.
import pandas as pd
from scripts.config import RAW_DATA_PATH

df = pd.read_csv(RAW_DATA_PATH + "/sales_pipeline.csv")
display(df.shape)
display(df.head())
# Out:
# (8800, 8)
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
# Generate and work with the processed dataset.
import pandas as pd
from scripts.config import PROCESSED_DATA_PATH
from scripts.data_preprocess import preprocess as data_preprocess

data_preprocess()
df = pd.read_csv(PROCESSED_DATA_PATH + "/dataset.csv")
display(df.shape)
display(df.head())
# Out:
# /home/ubuntu/code/MatthieuScarset/aisrm/data/raw
# 🤝 Preprocessed dataset exported: /home/ubuntu/code/MatthieuScarset/aisrm/data/processed/dataset.csv
# (6711, 15)
#    Unnamed: 0      sales_agent  account opportunity_status           manager  \
# 0           0      moses frase  cancity          completed  dustin brinkmann
# 1           1  darcel schlecht    isdom          completed     melvin marxen
# 2           2  darcel schlecht  cancity          completed     melvin marxen
# 3           3      moses frase  codehow          completed  dustin brinkmann
# 4           4        zane levy   hatfan          completed     summer sewald
#
#   regional_office    sector  revenue office_location         product series  \
# 0         central    retail   718.62   united states  gtx plus basic    gtx
# 1         central   medical  3178.24   united states          gtxpro    NaN
# 2         central    retail   718.62   united states      mg special     mg
# ...

# %%
df["won"].value_counts()
# Out:
# won
# 1    6711
# 0    2089
# Name: count, dtype: int64
